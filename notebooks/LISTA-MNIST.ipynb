# %% [markdown]
# ## MNIST
# Utilizes code from crino module. Run notebook with --pylab switch.

# %%
import numpy as np
import theano
import theano.tensor as T
import gzip, cPickle
from matplotlib import cm
import matplotlib.pyplot as plt
import matplotlib
# Out:
# Couldn't import dot_parser, loading of dot files will not be possible.
# Using gpu device 1: GeForce GTX 580

# %%
from osdfutils import crino
from osdfutils import misc

# %%
# uncomment next two lines if inline plotting should be enabled.
# %matplotlib inline
#matplotlib.rcParams['savefig.dpi'] = 144

# %%
# needs local mnist.pkl.gz
mnist_f = gzip.open("mnist.pkl.gz",'rb')                              
train_set, valid_set, test_set = cPickle.load(mnist_f)                
data = train_set[0]
trgts = train_set[1]
valid = valid_set[0]
mnist_f.close()

# %%
# %load_ext autoreload
# %autoreload 2
reload(crino)
# Out:
# <module 'osdfutils.crino' from '/home/osendorf/proj/utils/osdfutils/crino.pyc'>

# %%
epochs = 20
btsz = 100
lr = 0.1
momentum = 0.9
decay = 0.95
batches = data.shape[0]/btsz
print "LISTA -- Learned ISTA without ISTA"
print "Epochs", epochs
print "Batches per epoch", batches
print

Dinit = {"shape": (32*32, 28*28), "variant": "normal", "std": 0.1}
lmbd = 1 # sparsity weight
L = 1.
layers = 10
config = {"D": Dinit, "layers": layers, "L": L, "lambda": lmbd}
# normalize weights according to this config
norm_dic = {"D": {"axis":1, "c": 1.}}
# threshold theta should be at least some value
thresh_dic = {"theta": {"thresh": 1e-2}}

x, params, cost, rec, z = crino.lista(config=config, shrinkage=crino.sh)
grads = T.grad(cost, params)

# training ...
settings = {"lr": lr, "momentum": momentum, "decay": decay}
# ... with stochastic gradient + momentum
#updates = crino.momntm(params, grads, settings)#, **norm_dic)
updates = crino.adadelta(params, grads, settings)#, **norm_dic)
# ... normalize weights
updates = crino.norm_updt(params, updates, todo=norm_dic)
# ... make sure threshold is big enough
updates = crino.max_updt(params, updates, todo=thresh_dic)

train = theano.function([x], cost, updates=updates, 
                        allow_input_downcast=True)
print 'done.'
# Out:
# LISTA -- Learned ISTA without ISTA
# Epochs 20
# Batches per epoch 500
#
# [AdaDELTA] lr: 0.1; decay: 0.95
# [NORM_UPDT] D normalized to 1.0 along axis 1
# [MAX_UPDT] theta at least at 0.01
# done.

# %%
# Rerun this cell if another full number of epochs should be trained.
sz = data.shape[0]
for epoch in xrange(epochs):
    cost = 0
    for mbi in xrange(batches):
        cost += btsz*train(data[mbi*btsz:(mbi+1)*btsz])
    print epoch, cost/sz
# Out:
# 0 83.8994211502
# 1
#  64.1821108704
# 2
#  56.0229693756
# 3
#  51.2548640671
# 4
#  47.55264328
# 5
#  44.6024004974
# 6
#  42.1089187622
# 7
#  39.9394492111
# 8
#  38.0682887192
# 9
#  36.3814124374
# 10
#  34.9159658432
# 11
#  33.649122097
# 12
#  32.5899418564
# 13
#  31.6490846291
# 14
#  30.8432238121
# 15
#  30.1340736694
# 16
#  29.5129984894
# 17
#  28.9424941063
# 18
#  28.4229770775
# 19
#  27.9496237221

# %%
im = np.array(misc.visualize(params[0].get_value(), 28*28))
plt.imshow(im, cmap=cm.gray)
import Image as img
img.fromarray(im).save('D.png')

# %%
# show me the money
reconstructor = theano.function([x], rec, allow_input_downcast=True)
recs = reconstructor(valid[:14*14])
im = np.array(misc.visualize(recs, 28*28))
plt.imshow(im, cmap=cm.gray)

# %%
# %matplotlib inline
# visualize latents as sparse 2d images
reconstructor = theano.function([x], z, allow_input_downcast=True)
recs = reconstructor(valid[:14*14])
im = np.array(misc.visualize(recs, 6*6))
plt.imshow(im, cmap=cm.gray)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-94-862d0dc1c204> in <module>()
#       3 reconstructor = theano.function([x], z, allow_input_downcast=True)
#       4 recs = reconstructor(valid[:14*14])
# ----> 5 im = np.array(misc.visualize(recs, 6*6))
#       6 plt.imshow(im, cmap=cm.gray)
#
# /home/osendorf/proj/utils/osdfutils/misc.pyc in visualize(array, rsz, shape_r, xtiles, fill)
#     157         import PIL as img
#     158     sz = array.size
# --> 159     fields = array.reshape(sz/rsz, rsz)
#     160
#     161     # tiles per axes
#
# ValueError: total size of new array must be unchanged

# %%
# if sparse code size is not a square number, use matshow
plt.matshow(recs)
# for gray values
plt.matshow(recs, cmap=cm.gray)

# %%
# these should be 1, almost at least
np.sum(params[0].get_value()**2, axis=1)
# Out:
# array([ 0.99999881,  0.99999857,  0.99999917,  0.99999923,  0.99999893,
#         0.99999881,  0.99999881,  0.99999881,  0.99999958,  0.99999923,
#         0.99999952,  0.99999881,  0.99999881,  0.99999827,  0.99999899,
#         0.99999881,  0.99999857,  0.99999934,  0.99999845,  0.99999905,
#         0.99999946,  0.99999863,  0.99999869,  0.99999964,  0.99999881,
#         0.9999994 ,  0.99999845,  0.99999905,  0.99999911,  0.99999946,
#         0.99999881,  0.99999905,  0.99999964,  0.99999833,  0.99999857,
#         0.99999887,  0.99999881,  0.9999997 ,  0.99999899,  0.99999923,
#         0.99999827,  0.99999917,  0.99999821,  0.99999917,  0.99999857,
#         0.99999905,  0.99999875,  0.99999887,  0.99999863,  0.99999839,
#         0.99999863,  0.99999958,  0.99999875,  0.99999917,  0.99999845,
#         0.99999887,  0.99999893,  0.9999994 ,  0.99999845,  0.99999887,
#         0.99999863,  0.99999833,  0.99999887,  1.00000024,  0.99999911,
#         0.99999923,  0.99999881,  0.99999821,  0.99999887,  0.99999857,
#         0.99999928,  0.99999887,  0.99999899,  0.99999839,  0.99999869,
#         0.99999911,  0.99999881,  0.99999923,  0.99999946,  0.9999994 ,
#         0.99999851,  0.99999857,  0.99999863,  0.99999803,  0.99999911,
#         0.9999994 ,  0.99999899,  0.99999923,  0.99999923,  0.99999934,
#         0.99999845,  0.99999869,  0.99999934,  0.99999845,  0.99999887,
#         0.99999923,  0.99999911,  0.99999839,  0.99999875,  0.99999875,
#         0.99999845,  0.99999893,  0.99999875,  0.99999851,  0.99999928,
#         0.99999887,  0.99999934,  0.99999893,  0.99999875,  0.99999923,
#         0.99999899,  0.99999881,  0.99999833,  0.99999869,  0.99999911,
#         0.99999923,  0.99999851,  0.99999881,  0.99999934,  0.99999893,
#         0.99999905,  0.99999857,  0.99999851,  0.99999893,  0.99999905,
#         0.99999851,  0.99999869,  0.9999994 ,  0.99999869,  0.99999928,
#         0.99999946,  0.99999869,  0.99999928,  0.99999887,  0.99999899,
#         0.99999917,  0.99999839,  0.99999923,  0.99999905,  0.99999905,
#         0.99999887,  0.99999911,  0.99999946,  0.99999917,  0.99999893,
#         0.99999887,  0.99999875,  0.99999821,  0.9999994 ,  0.9999994 ,
#         0.99999893,  0.99999851,  0.99999875,  0.99999917,  0.99999875,
#         0.99999899,  0.99999946,  0.99999869,  0.99999887,  0.99999928,
#         0.99999863,  0.99999917,  0.99999964,  0.99999881,  0.99999934,
#         0.99999905,  0.99999964,  0.99999905,  0.99999863,  0.99999779,
#         0.99999881,  0.99999887,  0.99999887,  0.99999917,  0.99999869,
